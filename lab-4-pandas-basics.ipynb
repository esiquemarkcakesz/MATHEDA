# %% [markdown]
# # Pandas Basics <hr></hr>

# %% [markdown]
# <b> Mark Ian O. Esique</b>
# <br>Computer Engineer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # DataFrame

# %%
    # creating dictionary
data = {
    "Name": ['Henry', 'Owen', 'Ada'],
    "Age": [22, 35, 58],
    "Sex": ['M', 'M', 'F']
}

# %%
# creating dataframe from dictionary
df = pd.DataFrame(data)
df
# Out:
#     Name  Age Sex
# 0  Henry   22   M
# 1   Owen   35   M
# 2    Ada   58   F

# %% [markdown]
# # Series

# %%
# selecting 'Name' column
df['Name']
# Out:
# 0    Henry
# 1     Owen
# 2      Ada
# Name: Name, dtype: object

# %%
# selecting 'Age' column
df['Age']
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
# selecting 'Sex' column
df['Sex']
# Out:
# 0    M
# 1    M
# 2    F
# Name: Sex, dtype: object

# %% [markdown]
# # Descriptive Statistics

# %%
# Jaguar vs Panther
resistance = np.array([
    [10.6, 9.1, 9.3, 9.8, 10.5, 10.4, 9.5, 11.0, 4.3, 9.8],
    [10.1, 11.9, 9.1, 20.9, 2.8, 10.8, 9.9, 9.2, 9.1, np.nan]
]).T

resistance
# Out:
# array([[10.6, 10.1],
#        [ 9.1, 11.9],
#        [ 9.3,  9.1],
#        [ 9.8, 20.9],
#        [10.5,  2.8],
#        [10.4, 10.8],
#        [ 9.5,  9.9],
#        [11. ,  9.2],
#        [ 4.3,  9.1],
#        [ 9.8,  nan]])

# %%
# Creating DataFrame from numpy array
df = pd.DataFrame(resistance, columns=['Jaguar', 'Panther'])
df
# Out:
#    Jaguar  Panther
# 0    10.6     10.1
# 1     9.1     11.9
# 2     9.3      9.1
# 3     9.8     20.9
# 4    10.5      2.8
# 5    10.4     10.8
# 6     9.5      9.9
# 7    11.0      9.2
# 8     4.3      9.1
# 9     9.8      NaN

# %%
# Summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Jaguar   10 non-null     float64
#  1   Panther  9 non-null      float64
# dtypes: float64(2)
# memory usage: 292.0 bytes

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Summary of statistics
df.describe()
# Out:
#          Jaguar    Panther
# count  10.00000   9.000000
# mean    9.43000  10.422222
# std     1.90441   4.684757
# min     4.30000   2.800000
# 25%     9.35000   9.100000
# 50%     9.80000   9.900000
# 75%    10.47500  10.800000
# max    11.00000  20.900000

# %%
# Median
jag_median = df['Jaguar'].median()
pan_median = df['Panther'].median()

print(f'Jaguar Median = {jag_median:.2f} ohms')
print(f'Panther Median = {pan_median:.2f} ohms')
# Out:
# Jaguar Median = 9.80 ohms
# Panther Median = 9.90 ohms

# %%
# Mode
jag_mode = df['Jaguar'].mode()
pan_mode = df['Panther'].mode()

# %%
jag_mode
# Out:
# 0    9.8
# Name: Jaguar, dtype: float64

# %%
jag_mode.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1 entries, 0 to 0
# Series name: Jaguar
# Non-Null Count  Dtype
# --------------  -----
# 1 non-null      float64
# dtypes: float64(1)
# memory usage: 140.0 bytes

# %%
type(jag_mode)
# Out:
# pandas.core.series.Series

# %%
print('Jaguar Mode:')
for i in jag_mode:
    print(i)
# Out:
# Jaguar Mode:
# 9.8

# %%
print('Panther Mode:')
for i in pan_mode:
    print(i)
# Out:
# Panther Mode:
# 9.1

# %%
# Jaguar IQR
Q1 = df['Jaguar'].quantile(0.25)
Q3 = df['Jaguar'].quantile(0.75)

print(f'Jaguar IQR = {Q3-Q1:.2f} ohms')
# Out:
# Jaguar IQR = 1.12 ohms

# %%
# Panther IQR
Q1 = df['Panther'].quantile(0.25)
Q3 = df['Panther'].quantile(0.75)

print(f'Panther IQR = {Q3-Q1:.2f} ohms')
# Out:
# Panther IQR = 1.70 ohms

# %% [markdown]
# # Bar Chart

# %%
jag_mean = df['Jaguar'].mean()
pan_mean = df['Panther'].mean()

plt.figure(figsize=(7,4))
bars = plt.bar(['Jaguar', 'Panther'], [jag_mean, pan_mean],
               color='#126782')

plt.title('Average Resistance by Machine')
plt.ylabel('Resistance (ohms)')

# bar labels
plt.bar_label(bars, padding=3)
plt.margins(y=0.1)
plt.show()
